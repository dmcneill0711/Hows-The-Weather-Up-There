# %%
import pandas as pd

# %%
cities = "cities.csv"

city_data = pd.read_csv(cities)

# %%
city_data.head()
# Out:
#         City Country  Latitude  Longitude  Temperature  Humidity  Clouds  \
# 0     bethel      US   41.3712   -73.4140        19.75        54       0
# 1     barrow      US   71.2906  -156.7887         0.09        98      94
# 2  saskylakh      RU   71.9167   114.0833        -6.32        94      81
# 3     albany      US   42.6001   -73.9662        23.04        44      99
# 4  ituverava      BR  -20.3394   -47.7806        18.09        58       0
#
#    Wind_Speed
# 0        5.14
# 1        5.77
# 2        1.28
# 3        2.47
# 4        2.50

# %%
cities_df = pd.DataFrame(city_data)
cities_df
# Out:
#           City Country  Latitude  Longitude  Temperature  Humidity  Clouds  \
# 0       bethel      US   41.3712   -73.4140        19.75        54       0
# 1       barrow      US   71.2906  -156.7887         0.09        98      94
# 2    saskylakh      RU   71.9167   114.0833        -6.32        94      81
# 3       albany      US   42.6001   -73.9662        23.04        44      99
# 4    ituverava      BR  -20.3394   -47.7806        18.09        58       0
# ..         ...     ...       ...        ...          ...       ...     ...
# 570  juquitiba      BR  -23.9317   -47.0683        14.48        77       1
# 571   vallenar      CL  -28.5708   -70.7581        19.66        44      14
# 572   boralday      KZ   43.3578    76.8594        16.92        63      75
# 573    kodinsk      RU   58.6881    99.1844         9.18        96      23
# 574     valdez      EC    1.2492   -78.9831        26.19        81     100
#
#      Wind_Speed
# 0          5.14
# 1          5.77
# ...

# %%
cities_html = cities_df.to_html()

# %%
print(cities_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature</th>
#       <th>Humidity</th>
#       <th>Clouds</th>
#       <th>Wind_Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>bethel</td>
#       <td>US</td>
#       <td>41.3712</td>
#       <td>-73.4140</td>
#       <td>19.75</td>
#       <td>54</td>
#       <td>0</td>
#       <td>5.14</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>barrow</td>
#       <td>US</td>
#       <td>71.2906</td>
#       <td>-156.7887</td>
#       <td>0.09</td>
#       <td>98</td>
#       <td>94</td>
#       <td>5.77</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>saskylakh</td>
#       <td>RU</td>
#       <td>71.9167</td>
#       <td>114.0833</td>
#       <td>-6.32</td>
#       <td>94</td>
#       <td>81</td>
# ...
